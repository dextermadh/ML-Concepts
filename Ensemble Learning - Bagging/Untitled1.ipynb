# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
def z_score_outlier_removal(x, df):  
    df[f'zscore_{x}'] = (df[x] - df[x].mean()) / df[x].std()
    df2 = df[(df[f'zscore_{x}'] > -3) & (df[f'zscore_{x}'] < 3)]
    return df2

# %%
columns = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

for column in columns: 
    df2 = z_score_outlier_removal(column, df)

df2.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  zscore_Age  \
# 0              N      0.0       Up             0   -1.432359
# 1              N      1.0     Flat             1   -0.478223
# 2              N      0.0       Up             0   -1.750404
# 3              Y      1.5     Flat             1   -0.584238
# 4              N      0.0       Up             0    0.051853
#
#    zscore_RestingBP  zscore_Cholesterol  zscore_MaxHR  zscore_Oldpeak
# ...

# %%
df2.shape
# Out:
# (911, 17)

# %%
drop_columns = ['zscore_Age', 'zscore_RestingBP', 'zscore_Cholesterol', 'zscore_MaxHR', 'zscore_Oldpeak']
df2.drop(drop_columns, axis='columns', inplace=True)  
df2.head()
# Out:
# C:\Users\madhu\AppData\Local\Temp\ipykernel_15232\3093674159.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(drop_columns, axis='columns', inplace=True)
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# ...

# %%
df.Sex.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df.RestingBP.unique()
# Out:
# array([140, 160, 130, 138, 150, 120, 110, 136, 115, 100, 124, 113, 125,
#        145, 112, 132, 118, 170, 142, 190, 135, 180, 108, 155, 128, 106,
#         92, 200, 122,  98, 105, 133,  95,  80, 137, 185, 165, 126, 152,
#        116,   0, 144, 154, 134, 104, 139, 131, 141, 178, 146, 158, 123,
#        102,  96, 143, 172, 156, 114, 127, 101, 174,  94, 148, 117, 192,
#        129, 164])

# %%
df.FastingBS.unique()
# Out:
# array([0, 1])

# %%
df.RestingECG.unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df.ExerciseAngina.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df.ST_Slope.unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder 

le = LabelEncoder() 
dfle = df2

# %%
def lable_encode(x, df): 
    df[x] = le.fit_transform(df[x])

# %%
columns = ['Sex', 'ChestPainType', 'ExerciseAngina', 'ST_Slope'] 

for column in columns: 
    lable_encode(column, dfle) 

dfle.head()
# Out:
# C:\Users\madhu\AppData\Local\Temp\ipykernel_15232\1219301392.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[x] = le.fit_transform(df[x])
# C:\Users\madhu\AppData\Local\Temp\ipykernel_15232\1219301392.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[x] = le.fit_transform(df[x])
# C:\Users\madhu\AppData\Local\Temp\ipykernel_15232\1219301392.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dummies = pd.get_dummies(dfle[['RestingECG']], dtype='int64')
dummies.head()
# Out:
#    RestingECG_LVH  RestingECG_Normal  RestingECG_ST
# 0               0                  1              0
# 1               0                  1              0
# 2               0                  0              1
# 3               0                  1              0
# 4               0                  1              0

# %%
df3 = pd.concat([dfle, dummies], axis='columns')
df3.shape
# Out:
# (911, 15)

# %%
df3.drop('RestingECG', axis='columns', inplace=True)

# %%
df3.isnull().sum()
# Out:
# Age                  0
# Sex                  0
# ChestPainType        0
# RestingBP            0
# Cholesterol          0
# FastingBS            0
# MaxHR                0
# ExerciseAngina       0
# Oldpeak              0
# ST_Slope             0
# HeartDisease         0
# RestingECG_LVH       0
# RestingECG_Normal    0
# RestingECG_ST        0
# dtype: int64

# %%
X = df3.drop('HeartDisease', axis='columns')
y = df3.HeartDisease

# %%
df3.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  MaxHR  \
# 0   40    1              1        140          289          0    172
# 1   49    0              2        160          180          0    156
# 2   37    1              1        130          283          0     98
# 3   48    0              0        138          214          0    108
# 4   54    1              2        150          195          0    122
#
#    ExerciseAngina  Oldpeak  ST_Slope  HeartDisease  RestingECG_LVH  \
# 0               0      0.0         2             0               0
# 1               0      1.0         1             1               0
# 2               0      0.0         2             0               0
# 3               1      1.5         1             1               0
# 4               0      0.0         2             0               0
#
#    RestingECG_Normal  RestingECG_ST
# 0                  1              0
# 1                  1              0
# ...

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler() 
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.4286693 ,  0.51675676,  0.22649754, ..., -0.50650935,
#          0.81016272, -0.48761844],
#        [-0.47649408, -1.93514642,  1.27390492, ..., -0.50650935,
#          0.81016272, -0.48761844],
#        [-1.74606104,  0.51675676,  0.22649754, ..., -0.50650935,
#         -1.23431994,  2.05078382],
#        ...,
#        [ 0.3698839 ,  0.51675676, -0.82090985, ..., -0.50650935,
#          0.81016272, -0.48761844],
#        [ 0.3698839 , -1.93514642,  0.22649754, ...,  1.97429721,
#         -1.23431994, -0.48761844],
#        [-1.6402638 ,  0.51675676,  1.27390492, ..., -0.50650935,
#          0.81016272, -0.48761844]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=30)

# %%
from sklearn.svm import SVC 
model = SVC(C=10, kernel='rbf', gamma='auto')
model.fit(X_train, y_train)
# Out:
# SVC(C=10, gamma='auto')

# %%
model.score(X_test, y_test)
# Out:
# 0.8961748633879781

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag_model = BaggingClassifier(
    estimator=SVC(), 
    n_estimators=50, 
    max_samples=0.8,  
    oob_score=True,
    random_state=0 
)

bag_model.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=SVC(), max_samples=0.8, n_estimators=50,
#                   oob_score=True, random_state=0)

# %%
bag_model.score(X_test, y_test)
# Out:
# 0.8852459016393442

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier() 
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.8032786885245902

# %%
bag_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(), 
    n_estimators=100, 
    max_samples=0.8, 
    oob_score=True, 
    random_state=0
)
bag_model.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=0.8,
#                   n_estimators=100, oob_score=True, random_state=0)

# %%
bag_model.score(X_test, y_test)
# Out:
# 0.8907103825136612
